# %%
import json
with open('../src/lib/vendors.json', 'r') as f:
    v = json.load(f)

# %%
vendors = [x['slug'] for x in v['vendors']]

# %%
urls = [
    '/',
    '/features/versioning',
    '/features/realtime-collaboration'
]

# %%
for v in vendors:
    url = f'/alternatives/{v}'
    urls.append(url)
    print(f"'{url}',")
# Out:
# '/alternatives/jupyter',
# '/alternatives/sagemaker',
# '/alternatives/colab',
# '/alternatives/deepnote',
# '/alternatives/databricks',
# '/alternatives/cocalc',
# '/alternatives/hex',
# '/alternatives/kaggle',
# '/alternatives/bento',
# '/alternatives/nextjournal',
# '/alternatives/datalore',
# '/alternatives/observable',
# '/alternatives/vscode',
# '/alternatives/mode',
# '/alternatives/zepl',
# '/alternatives/polynote',
# '/alternatives/zeppelin',
# '/alternatives/count',
# '/alternatives/nteract',
# '/alternatives/pluto',

# %%
import itertools
for v1, v2 in itertools.combinations(vendors, 2):
    url = f'/compare/{v1}/{v2}'
    urls.append(url)
    print(f"'{url}',")
    print(f"'{url}',")
# Out:
# '/compare/jupyter/sagemaker',
# '/compare/jupyter/sagemaker',
# '/compare/jupyter/colab',
# '/compare/jupyter/colab',
# '/compare/jupyter/deepnote',
# '/compare/jupyter/deepnote',
# '/compare/jupyter/databricks',
# '/compare/jupyter/databricks',
# '/compare/jupyter/cocalc',
# '/compare/jupyter/cocalc',
# '/compare/jupyter/hex',
# '/compare/jupyter/hex',
# '/compare/jupyter/kaggle',
# '/compare/jupyter/kaggle',
# '/compare/jupyter/bento',
# '/compare/jupyter/bento',
# '/compare/jupyter/nextjournal',
# '/compare/jupyter/nextjournal',
# '/compare/jupyter/datalore',
# '/compare/jupyter/datalore',
# '/compare/jupyter/observable',
# '/compare/jupyter/observable',
# '/compare/jupyter/vscode',
# '/compare/jupyter/vscode',
# '/compare/jupyter/mode',
# '/compare/jupyter/mode',
# '/compare/jupyter/zepl',
# '/compare/jupyter/zepl',
# '/compare/jupyter/polynote',
# '/compare/jupyter/polynote',
# '/compare/jupyter/zeppelin',
# '/compare/jupyter/zeppelin',
# '/compare/jupyter/count',
# '/compare/jupyter/count',
# '/compare/jupyter/nteract',
# '/compare/jupyter/nteract',
# '/compare/jupyter/pluto',
# '/compare/jupyter/pluto',
# '/compare/sagemaker/colab',
# '/compare/sagemaker/colab',
# '/compare/sagemaker/deepnote',
# '/compare/sagemaker/deepnote',
# '/compare/sagemaker/databricks',
# '/compare/sagemaker/databricks',
# '/compare/sagemaker/cocalc',
# '/compare/sagemaker/cocalc',
# '/compare/sagemaker/hex',
# '/compare/sagemaker/hex',
# '/compare/sagemaker/kaggle',
# '/compare/sagemaker/kaggle',
# '/compare/sagemaker/bento',
# '/compare/sagemaker/bento',
# '/compare/sagemaker/nextjournal',
# '/compare/sagemaker/nextjournal',
# '/compare/sagemaker/datalore',
# '/compare/sagemaker/datalore',
# '/compare/sagemaker/observable',
# '/compare/sagemaker/observable',
# '/compare/sagemaker/vscode',
# '/compare/sagemaker/vscode',
# '/compare/sagemaker/mode',
# '/compare/sagemaker/mode',
# '/compare/sagemaker/zepl',
# '/compare/sagemaker/zepl',
# '/compare/sagemaker/polynote',
# '/compare/sagemaker/polynote',
# '/compare/sagemaker/zeppelin',
# '/compare/sagemaker/zeppelin',
# '/compare/sagemaker/count',
# '/compare/sagemaker/count',
# '/compare/sagemaker/nteract',
# '/compare/sagemaker/nteract',
# '/compare/sagemaker/pluto',
# '/compare/sagemaker/pluto',
# '/compare/colab/deepnote',
# '/compare/colab/deepnote',
# '/compare/colab/databricks',
# '/compare/colab/databricks',
# '/compare/colab/cocalc',
# '/compare/colab/cocalc',
# '/compare/colab/hex',
# '/compare/colab/hex',
# '/compare/colab/kaggle',
# '/compare/colab/kaggle',
# '/compare/colab/bento',
# '/compare/colab/bento',
# '/compare/colab/nextjournal',
# '/compare/colab/nextjournal',
# '/compare/colab/datalore',
# '/compare/colab/datalore',
# '/compare/colab/observable',
# '/compare/colab/observable',
# '/compare/colab/vscode',
# '/compare/colab/vscode',
# '/compare/colab/mode',
# '/compare/colab/mode',
# '/compare/colab/zepl',
# '/compare/colab/zepl',
# '/compare/colab/polynote',
# '/compare/colab/polynote',
# '/compare/colab/zeppelin',
# '/compare/colab/zeppelin',
# '/compare/colab/count',
# '/compare/colab/count',
# '/compare/colab/nteract',
# '/compare/colab/nteract',
# '/compare/colab/pluto',
# '/compare/colab/pluto',
# '/compare/deepnote/databricks',
# '/compare/deepnote/databricks',
# '/compare/deepnote/cocalc',
# '/compare/deepnote/cocalc',
# '/compare/deepnote/hex',
# '/compare/deepnote/hex',
# '/compare/deepnote/kaggle',
# '/compare/deepnote/kaggle',
# '/compare/deepnote/bento',
# '/compare/deepnote/bento',
# '/compare/deepnote/nextjournal',
# '/compare/deepnote/nextjournal',
# '/compare/deepnote/datalore',
# '/compare/deepnote/datalore',
# '/compare/deepnote/observable',
# '/compare/deepnote/observable',
# '/compare/deepnote/vscode',
# '/compare/deepnote/vscode',
# '/compare/deepnote/mode',
# '/compare/deepnote/mode',
# '/compare/deepnote/zepl',
# '/compare/deepnote/zepl',
# '/compare/deepnote/polynote',
# '/compare/deepnote/polynote',
# '/compare/deepnote/zeppelin',
# '/compare/deepnote/zeppelin',
# '/compare/deepnote/count',
# '/compare/deepnote/count',
# '/compare/deepnote/nteract',
# '/compare/deepnote/nteract',
# '/compare/deepnote/pluto',
# '/compare/deepnote/pluto',
# '/compare/databricks/cocalc',
# '/compare/databricks/cocalc',
# '/compare/databricks/hex',
# '/compare/databricks/hex',
# '/compare/databricks/kaggle',
# '/compare/databricks/kaggle',
# '/compare/databricks/bento',
# '/compare/databricks/bento',
# '/compare/databricks/nextjournal',
# '/compare/databricks/nextjournal',
# '/compare/databricks/datalore',
# '/compare/databricks/datalore',
# '/compare/databricks/observable',
# '/compare/databricks/observable',
# '/compare/databricks/vscode',
# '/compare/databricks/vscode',
# '/compare/databricks/mode',
# '/compare/databricks/mode',
# '/compare/databricks/zepl',
# '/compare/databricks/zepl',
# '/compare/databricks/polynote',
# '/compare/databricks/polynote',
# '/compare/databricks/zeppelin',
# '/compare/databricks/zeppelin',
# '/compare/databricks/count',
# '/compare/databricks/count',
# '/compare/databricks/nteract',
# '/compare/databricks/nteract',
# '/compare/databricks/pluto',
# '/compare/databricks/pluto',
# '/compare/cocalc/hex',
# '/compare/cocalc/hex',
# '/compare/cocalc/kaggle',
# '/compare/cocalc/kaggle',
# '/compare/cocalc/bento',
# '/compare/cocalc/bento',
# '/compare/cocalc/nextjournal',
# '/compare/cocalc/nextjournal',
# '/compare/cocalc/datalore',
# '/compare/cocalc/datalore',
# '/compare/cocalc/observable',
# '/compare/cocalc/observable',
# '/compare/cocalc/vscode',
# '/compare/cocalc/vscode',
# '/compare/cocalc/mode',
# '/compare/cocalc/mode',
# '/compare/cocalc/zepl',
# '/compare/cocalc/zepl',
# '/compare/cocalc/polynote',
# '/compare/cocalc/polynote',
# '/compare/cocalc/zeppelin',
# '/compare/cocalc/zeppelin',
# '/compare/cocalc/count',
# '/compare/cocalc/count',
# '/compare/cocalc/nteract',
# '/compare/cocalc/nteract',
# '/compare/cocalc/pluto',
# '/compare/cocalc/pluto',
# '/compare/hex/kaggle',
# '/compare/hex/kaggle',
# '/compare/hex/bento',
# '/compare/hex/bento',
# '/compare/hex/nextjournal',
# '/compare/hex/nextjournal',
# '/compare/hex/datalore',
# '/compare/hex/datalore',
# '/compare/hex/observable',
# '/compare/hex/observable',
# '/compare/hex/vscode',
# '/compare/hex/vscode',
# '/compare/hex/mode',
# '/compare/hex/mode',
# '/compare/hex/zepl',
# '/compare/hex/zepl',
# '/compare/hex/polynote',
# '/compare/hex/polynote',
# '/compare/hex/zeppelin',
# '/compare/hex/zeppelin',
# '/compare/hex/count',
# '/compare/hex/count',
# '/compare/hex/nteract',
# '/compare/hex/nteract',
# '/compare/hex/pluto',
# '/compare/hex/pluto',
# '/compare/kaggle/bento',
# '/compare/kaggle/bento',
# '/compare/kaggle/nextjournal',
# '/compare/kaggle/nextjournal',
# '/compare/kaggle/datalore',
# '/compare/kaggle/datalore',
# '/compare/kaggle/observable',
# '/compare/kaggle/observable',
# '/compare/kaggle/vscode',
# '/compare/kaggle/vscode',
# '/compare/kaggle/mode',
# '/compare/kaggle/mode',
# '/compare/kaggle/zepl',
# '/compare/kaggle/zepl',
# '/compare/kaggle/polynote',
# '/compare/kaggle/polynote',
# '/compare/kaggle/zeppelin',
# '/compare/kaggle/zeppelin',
# '/compare/kaggle/count',
# '/compare/kaggle/count',
# '/compare/kaggle/nteract',
# '/compare/kaggle/nteract',
# '/compare/kaggle/pluto',
# '/compare/kaggle/pluto',
# '/compare/bento/nextjournal',
# '/compare/bento/nextjournal',
# '/compare/bento/datalore',
# '/compare/bento/datalore',
# '/compare/bento/observable',
# '/compare/bento/observable',
# '/compare/bento/vscode',
# '/compare/bento/vscode',
# '/compare/bento/mode',
# '/compare/bento/mode',
# '/compare/bento/zepl',
# '/compare/bento/zepl',
# '/compare/bento/polynote',
# '/compare/bento/polynote',
# '/compare/bento/zeppelin',
# '/compare/bento/zeppelin',
# '/compare/bento/count',
# '/compare/bento/count',
# '/compare/bento/nteract',
# '/compare/bento/nteract',
# '/compare/bento/pluto',
# '/compare/bento/pluto',
# '/compare/nextjournal/datalore',
# '/compare/nextjournal/datalore',
# '/compare/nextjournal/observable',
# '/compare/nextjournal/observable',
# '/compare/nextjournal/vscode',
# '/compare/nextjournal/vscode',
# '/compare/nextjournal/mode',
# '/compare/nextjournal/mode',
# '/compare/nextjournal/zepl',
# '/compare/nextjournal/zepl',
# '/compare/nextjournal/polynote',
# '/compare/nextjournal/polynote',
# '/compare/nextjournal/zeppelin',
# '/compare/nextjournal/zeppelin',
# '/compare/nextjournal/count',
# '/compare/nextjournal/count',
# '/compare/nextjournal/nteract',
# '/compare/nextjournal/nteract',
# '/compare/nextjournal/pluto',
# '/compare/nextjournal/pluto',
# '/compare/datalore/observable',
# '/compare/datalore/observable',
# '/compare/datalore/vscode',
# '/compare/datalore/vscode',
# '/compare/datalore/mode',
# '/compare/datalore/mode',
# '/compare/datalore/zepl',
# '/compare/datalore/zepl',
# '/compare/datalore/polynote',
# '/compare/datalore/polynote',
# '/compare/datalore/zeppelin',
# '/compare/datalore/zeppelin',
# '/compare/datalore/count',
# '/compare/datalore/count',
# '/compare/datalore/nteract',
# '/compare/datalore/nteract',
# '/compare/datalore/pluto',
# '/compare/datalore/pluto',
# '/compare/observable/vscode',
# '/compare/observable/vscode',
# '/compare/observable/mode',
# '/compare/observable/mode',
# '/compare/observable/zepl',
# '/compare/observable/zepl',
# '/compare/observable/polynote',
# '/compare/observable/polynote',
# '/compare/observable/zeppelin',
# '/compare/observable/zeppelin',
# '/compare/observable/count',
# '/compare/observable/count',
# '/compare/observable/nteract',
# '/compare/observable/nteract',
# '/compare/observable/pluto',
# '/compare/observable/pluto',
# '/compare/vscode/mode',
# '/compare/vscode/mode',
# '/compare/vscode/zepl',
# '/compare/vscode/zepl',
# '/compare/vscode/polynote',
# '/compare/vscode/polynote',
# '/compare/vscode/zeppelin',
# '/compare/vscode/zeppelin',
# '/compare/vscode/count',
# '/compare/vscode/count',
# '/compare/vscode/nteract',
# '/compare/vscode/nteract',
# '/compare/vscode/pluto',
# '/compare/vscode/pluto',
# '/compare/mode/zepl',
# '/compare/mode/zepl',
# '/compare/mode/polynote',
# '/compare/mode/polynote',
# '/compare/mode/zeppelin',
# '/compare/mode/zeppelin',
# '/compare/mode/count',
# '/compare/mode/count',
# '/compare/mode/nteract',
# '/compare/mode/nteract',
# '/compare/mode/pluto',
# '/compare/mode/pluto',
# '/compare/zepl/polynote',
# '/compare/zepl/polynote',
# '/compare/zepl/zeppelin',
# '/compare/zepl/zeppelin',
# '/compare/zepl/count',
# '/compare/zepl/count',
# '/compare/zepl/nteract',
# '/compare/zepl/nteract',
# '/compare/zepl/pluto',
# '/compare/zepl/pluto',
# '/compare/polynote/zeppelin',
# '/compare/polynote/zeppelin',
# '/compare/polynote/count',
# '/compare/polynote/count',
# '/compare/polynote/nteract',
# '/compare/polynote/nteract',
# '/compare/polynote/pluto',
# '/compare/polynote/pluto',
# '/compare/zeppelin/count',
# '/compare/zeppelin/count',
# '/compare/zeppelin/nteract',
# '/compare/zeppelin/nteract',
# '/compare/zeppelin/pluto',
# '/compare/zeppelin/pluto',
# '/compare/count/nteract',
# '/compare/count/nteract',
# '/compare/count/pluto',
# '/compare/count/pluto',
# '/compare/nteract/pluto',
# '/compare/nteract/pluto',

# %%
urls
# Out:
# ['/',
#  '/features/versioning',
#  '/features/realtime-collaboration',
#  '/alternatives/jupyter',
#  '/alternatives/sagemaker',
#  '/alternatives/colab',
#  '/alternatives/deepnote',
#  '/alternatives/databricks',
#  '/alternatives/cocalc',
#  '/alternatives/hex',
#  '/alternatives/kaggle',
#  '/alternatives/bento',
#  '/alternatives/nextjournal',
#  '/alternatives/datalore',
#  '/alternatives/observable',
#  '/alternatives/vscode',
#  '/alternatives/mode',
#  '/alternatives/zepl',
#  '/alternatives/polynote',
#  '/alternatives/zeppelin',
#  '/alternatives/count',
#  '/alternatives/nteract',
#  '/alternatives/pluto',
#  '/compare/jupyter/sagemaker',
#  '/compare/jupyter/colab',
#  '/compare/jupyter/deepnote',
#  '/compare/jupyter/databricks',
#  '/compare/jupyter/cocalc',
#  '/compare/jupyter/hex',
#  '/compare/jupyter/kaggle',
#  '/compare/jupyter/bento',
#  '/compare/jupyter/nextjournal',
#  '/compare/jupyter/datalore',
#  '/compare/jupyter/observable',
#  '/compare/jupyter/vscode',
#  '/compare/jupyter/mode',
#  '/compare/jupyter/zepl',
#  '/compare/jupyter/polynote',
#  '/compare/jupyter/zeppelin',
#  '/compare/jupyter/count',
#  '/compare/jupyter/nteract',
#  '/compare/jupyter/pluto',
#  '/compare/sagemaker/colab',
#  '/compare/sagemaker/deepnote',
#  '/compare/sagemaker/databricks',
#  '/compare/sagemaker/cocalc',
#  '/compare/sagemaker/hex',
#  '/compare/sagemaker/kaggle',
#  '/compare/sagemaker/bento',
#  '/compare/sagemaker/nextjournal',
#  '/compare/sagemaker/datalore',
#  '/compare/sagemaker/observable',
#  '/compare/sagemaker/vscode',
#  '/compare/sagemaker/mode',
#  '/compare/sagemaker/zepl',
#  '/compare/sagemaker/polynote',
#  '/compare/sagemaker/zeppelin',
#  '/compare/sagemaker/count',
#  '/compare/sagemaker/nteract',
#  '/compare/sagemaker/pluto',
#  '/compare/colab/deepnote',
#  '/compare/colab/databricks',
#  '/compare/colab/cocalc',
#  '/compare/colab/hex',
#  '/compare/colab/kaggle',
#  '/compare/colab/bento',
#  '/compare/colab/nextjournal',
#  '/compare/colab/datalore',
#  '/compare/colab/observable',
#  '/compare/colab/vscode',
#  '/compare/colab/mode',
#  '/compare/colab/zepl',
#  '/compare/colab/polynote',
#  '/compare/colab/zeppelin',
#  '/compare/colab/count',
#  '/compare/colab/nteract',
#  '/compare/colab/pluto',
#  '/compare/deepnote/databricks',
#  '/compare/deepnote/cocalc',
#  '/compare/deepnote/hex',
#  '/compare/deepnote/kaggle',
#  '/compare/deepnote/bento',
#  '/compare/deepnote/nextjournal',
#  '/compare/deepnote/datalore',
#  '/compare/deepnote/observable',
#  '/compare/deepnote/vscode',
#  '/compare/deepnote/mode',
#  '/compare/deepnote/zepl',
#  '/compare/deepnote/polynote',
#  '/compare/deepnote/zeppelin',
#  '/compare/deepnote/count',
#  '/compare/deepnote/nteract',
#  '/compare/deepnote/pluto',
#  '/compare/databricks/cocalc',
#  '/compare/databricks/hex',
#  '/compare/databricks/kaggle',
#  '/compare/databricks/bento',
#  '/compare/databricks/nextjournal',
#  '/compare/databricks/datalore',
#  '/compare/databricks/observable',
#  '/compare/databricks/vscode',
#  '/compare/databricks/mode',
#  '/compare/databricks/zepl',
#  '/compare/databricks/polynote',
#  '/compare/databricks/zeppelin',
#  '/compare/databricks/count',
#  '/compare/databricks/nteract',
#  '/compare/databricks/pluto',
#  '/compare/cocalc/hex',
#  '/compare/cocalc/kaggle',
#  '/compare/cocalc/bento',
#  '/compare/cocalc/nextjournal',
#  '/compare/cocalc/datalore',
#  '/compare/cocalc/observable',
#  '/compare/cocalc/vscode',
#  '/compare/cocalc/mode',
#  '/compare/cocalc/zepl',
#  '/compare/cocalc/polynote',
#  '/compare/cocalc/zeppelin',
#  '/compare/cocalc/count',
#  '/compare/cocalc/nteract',
#  '/compare/cocalc/pluto',
#  '/compare/hex/kaggle',
#  '/compare/hex/bento',
#  '/compare/hex/nextjournal',
#  '/compare/hex/datalore',
#  '/compare/hex/observable',
#  '/compare/hex/vscode',
#  '/compare/hex/mode',
#  '/compare/hex/zepl',
#  '/compare/hex/polynote',
#  '/compare/hex/zeppelin',
#  '/compare/hex/count',
#  '/compare/hex/nteract',
#  '/compare/hex/pluto',
#  '/compare/kaggle/bento',
#  '/compare/kaggle/nextjournal',
#  '/compare/kaggle/datalore',
#  '/compare/kaggle/observable',
#  '/compare/kaggle/vscode',
#  '/compare/kaggle/mode',
#  '/compare/kaggle/zepl',
#  '/compare/kaggle/polynote',
#  '/compare/kaggle/zeppelin',
#  '/compare/kaggle/count',
#  '/compare/kaggle/nteract',
#  '/compare/kaggle/pluto',
#  '/compare/bento/nextjournal',
#  '/compare/bento/datalore',
#  '/compare/bento/observable',
#  '/compare/bento/vscode',
#  '/compare/bento/mode',
#  '/compare/bento/zepl',
#  '/compare/bento/polynote',
#  '/compare/bento/zeppelin',
#  '/compare/bento/count',
#  '/compare/bento/nteract',
#  '/compare/bento/pluto',
#  '/compare/nextjournal/datalore',
#  '/compare/nextjournal/observable',
#  '/compare/nextjournal/vscode',
#  '/compare/nextjournal/mode',
#  '/compare/nextjournal/zepl',
#  '/compare/nextjournal/polynote',
#  '/compare/nextjournal/zeppelin',
#  '/compare/nextjournal/count',
#  '/compare/nextjournal/nteract',
#  '/compare/nextjournal/pluto',
#  '/compare/datalore/observable',
#  '/compare/datalore/vscode',
#  '/compare/datalore/mode',
#  '/compare/datalore/zepl',
#  '/compare/datalore/polynote',
#  '/compare/datalore/zeppelin',
#  '/compare/datalore/count',
#  '/compare/datalore/nteract',
#  '/compare/datalore/pluto',
#  '/compare/observable/vscode',
#  '/compare/observable/mode',
#  '/compare/observable/zepl',
#  '/compare/observable/polynote',
#  '/compare/observable/zeppelin',
#  '/compare/observable/count',
#  '/compare/observable/nteract',
#  '/compare/observable/pluto',
#  '/compare/vscode/mode',
#  '/compare/vscode/zepl',
#  '/compare/vscode/polynote',
#  '/compare/vscode/zeppelin',
#  '/compare/vscode/count',
#  '/compare/vscode/nteract',
#  '/compare/vscode/pluto',
#  '/compare/mode/zepl',
#  '/compare/mode/polynote',
#  '/compare/mode/zeppelin',
#  '/compare/mode/count',
#  '/compare/mode/nteract',
#  '/compare/mode/pluto',
#  '/compare/zepl/polynote',
#  '/compare/zepl/zeppelin',
#  '/compare/zepl/count',
#  '/compare/zepl/nteract',
#  '/compare/zepl/pluto',
#  '/compare/polynote/zeppelin',
#  '/compare/polynote/count',
#  '/compare/polynote/nteract',
#  '/compare/polynote/pluto',
#  '/compare/zeppelin/count',
#  '/compare/zeppelin/nteract',
#  '/compare/zeppelin/pluto',
#  '/compare/count/nteract',
#  '/compare/count/pluto',
#  '/compare/nteract/pluto']

# %%
import xml.etree.cElementTree as ET
import datetime

root = ET.Element('urlset')
root.attrib['xmlns:xsi']="http://www.w3.org/2001/XMLSchema-instance"
root.attrib['xsi:schemaLocation']="http://www.sitemaps.org/schemas/sitemap/0.9 http://www.sitemaps.org/schemas/sitemap/0.9/sitemap.xsd"
root.attrib['xmlns']="http://www.sitemaps.org/schemas/sitemap/0.9"

for url in urls:
    dt = datetime.datetime.now().strftime ("%Y-%m-%d")
    doc = ET.SubElement(root, "url")
    ET.SubElement(doc, "loc").text = "https://datasciencenotebook.org"+url
    ET.SubElement(doc, "lastmod").text = dt
    ET.SubElement(doc, "changefreq").text = "weekly"
    ET.SubElement(doc, "priority").text = "1.0"

tree = ET.ElementTree(root)
tree.write('../static/sitemap.xml', encoding='utf-8', xml_declaration=True)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=d391d205-19c3-4542-b8d3-26ed01b7ba99' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
